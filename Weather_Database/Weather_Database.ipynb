# %%
#Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a set of random lat and long combinations
lats= np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs= np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs= zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list
coordinates= list(lat_lngs)

# %%
#Import citipy module
from citipy import citipy

# %%
#Create a list for holding the cities
cities= []
#Identify the nearest city for each lat and long combo
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    #If the city is unique, add it to cities list
    if city not in cities:
        cities.append(city)
#Print the city count to confirm sufficient count
len(cities)
# Out:
# 763

# %%
#Import the requests library
import requests
#Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data
city_data=[]
#Print the beginning of the logging
print("Beginning Data Retrieval    ")
print("----------------------------")

#Create counters
record_count= 1
set_count= 1

#Loop through all the cities in list
for i, city in enumerate(cities):
    #Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count+= 1
        record_count= 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 to the record count
    record_count += 1
    #Run an API request for each of the cities
    try:
        #Parse the JSON and retrieve data
        city_weather= requests.get(city_url).json()
        #Parse out the needed data
        city_lat= city_weather["coord"]["lat"]
        city_lng= city_weather["coord"]["lon"]
        city_max_temp= city_weather["main"]["temp_max"]
        city_humidity= city_weather["main"]["humidity"]
        city_clouds= city_weather["clouds"]["all"]
        city_wind= city_weather["wind"]["speed"]
        city_country= city_weather["sys"]["country"]
        city_current= city_weather["weather"][0]["description"]
        #Append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current})
    #If an error is experienced, skip the city
    except Exception as e:
        print (e)
        print("City not found. Skipping...")
        pass
#Indidate that Data Loading is complete
print("----------------------------")
print("Data Retrieval Complete     ")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | helong
# Processing Record 2 of Set 1 | viligili
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 1 | kavaratti
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | vila do maio
# Processing Record 7 of Set 1 | savonlinna
# Processing Record 8 of Set 1 | college
# Processing Record 9 of Set 1 | charters towers
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | bandarbeyla
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | le vauclin
# Processing Record 14 of Set 1 | mwene-ditu
# Processing Record 15 of Set 1 | chokurdakh
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | jacqueville
# Processing Record 18 of Set 1 | akureyri
# Processing Record 19 of Set 1 | yeppoon
# Processing Record 20 of Set 1 | guelengdeng
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 1 | upernavik
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | gushi
# Processing Record 25 of Set 1 | imbituba
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | sentyabrskiy
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 1 | norfolk
# Processing Record 29 of Set 1 | bagaces
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | karlovac
# Processing Record 32 of Set 1 | vostok
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | lompoc
# Processing Record 35 of Set 1 | quang ngai
# Processing Record 36 of Set 1 | belushya guba
# 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 1 | luderitz
# Processing Record 38 of Set 1 | sola
# Processing Record 39 of Set 1 | saint-pierre
# Processing Record 40 of Set 1 | grindavik
# Processing Record 41 of Set 1 | egvekinot
# Processing Record 42 of Set 1 | avarua
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | am timan
# Processing Record 45 of Set 1 | fallon
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | torbay
# Processing Record 48 of Set 1 | sept-iles
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 1 of Set 2 | tuggurt
# 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 2 | tsumeb
# Processing Record 3 of Set 2 | clyde river
# Processing Record 4 of Set 2 | qaanaaq
# Processing Record 5 of Set 2 | marsh harbour
# Processing Record 6 of Set 2 | la palma
# Processing Record 7 of Set 2 | east london
# Processing Record 8 of Set 2 | faanui
# Processing Record 9 of Set 2 | alta floresta
# Processing Record 10 of Set 2 | mys shmidta
# 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 2 | araouane
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | kaitangata
# Processing Record 14 of Set 2 | attawapiskat
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 2 | vihti
# Processing Record 16 of Set 2 | taolanaro
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 2 | kalmunai
# Processing Record 18 of Set 2 | namatanai
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | macomer
# Processing Record 21 of Set 2 | makakilo city
# Processing Record 22 of Set 2 | illoqqortoormiut
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 2 | puerto narino
# Processing Record 24 of Set 2 | hithadhoo
# Processing Record 25 of Set 2 | san cristobal
# Processing Record 26 of Set 2 | nizhneyansk
# 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | nhulunbuy
# Processing Record 29 of Set 2 | palmas de monte alto
# Processing Record 30 of Set 2 | agua blanca
# Processing Record 31 of Set 2 | pangnirtung
# Processing Record 32 of Set 2 | plettenberg bay
# Processing Record 33 of Set 2 | norman wells
# Processing Record 34 of Set 2 | santa isabel
# Processing Record 35 of Set 2 | hilo
# Processing Record 36 of Set 2 | beringovskiy
# Processing Record 37 of Set 2 | grand forks
# Processing Record 38 of Set 2 | cururupu
# Processing Record 39 of Set 2 | georgetown
# Processing Record 40 of Set 2 | sur
# Processing Record 41 of Set 2 | albany
# Processing Record 42 of Set 2 | severo-yeniseyskiy
# Processing Record 43 of Set 2 | rudnogorsk
# Processing Record 44 of Set 2 | kruisfontein
# Processing Record 45 of Set 2 | allapalli
# Processing Record 46 of Set 2 | lure
# Processing Record 47 of Set 2 | slave lake
# Processing Record 48 of Set 2 | chumikan
# Processing Record 49 of Set 2 | orneta
# Processing Record 50 of Set 2 | bredasdorp
# Processing Record 1 of Set 3 | beloha
# Processing Record 2 of Set 3 | ambilobe
# Processing Record 3 of Set 3 | hobyo
# Processing Record 4 of Set 3 | tiksi
# Processing Record 5 of Set 3 | saskylakh
# Processing Record 6 of Set 3 | cabo san lucas
# Processing Record 7 of Set 3 | inhambane
# Processing Record 8 of Set 3 | ziro
# Processing Record 9 of Set 3 | haines junction
# Processing Record 10 of Set 3 | jabiru
# 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 3 | barentsburg
# 'coord'
# City not found. Skipping...
# Processing Record 12 of Set 3 | manaure
# Processing Record 13 of Set 3 | carutapera
# Processing Record 14 of Set 3 | hermanus
# Processing Record 15 of Set 3 | praia da vitoria
# Processing Record 16 of Set 3 | naze
# Processing Record 17 of Set 3 | camana
# Processing Record 18 of Set 3 | batemans bay
# Processing Record 19 of Set 3 | jaicos
# Processing Record 20 of Set 3 | mozirje
# Processing Record 21 of Set 3 | camacha
# Processing Record 22 of Set 3 | faya
# Processing Record 23 of Set 3 | ancud
# Processing Record 24 of Set 3 | mizdah
# Processing Record 25 of Set 3 | moyale
# Processing Record 26 of Set 3 | buraydah
# Processing Record 27 of Set 3 | boli
# Processing Record 28 of Set 3 | bolungarvik
# 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 3 | provideniya
# Processing Record 30 of Set 3 | soubre
# Processing Record 31 of Set 3 | kupang
# Processing Record 32 of Set 3 | ende
# Processing Record 33 of Set 3 | sao sebastiao
# Processing Record 34 of Set 3 | nantucket
# Processing Record 35 of Set 3 | eyl
# Processing Record 36 of Set 3 | maumere
# Processing Record 37 of Set 3 | khromtau
# Processing Record 38 of Set 3 | milton
# Processing Record 39 of Set 3 | quesnel
# Processing Record 40 of Set 3 | miri
# Processing Record 41 of Set 3 | hanzhong
# Processing Record 42 of Set 3 | logstor
# Processing Record 43 of Set 3 | irbit
# Processing Record 44 of Set 3 | minbu
# Processing Record 45 of Set 3 | ngukurr
# 'coord'
# City not found. Skipping...
# Processing Record 46 of Set 3 | henties bay
# Processing Record 47 of Set 3 | moose factory
# Processing Record 48 of Set 3 | shaunavon
# Processing Record 49 of Set 3 | bac lieu
# Processing Record 50 of Set 3 | brenes
# Processing Record 1 of Set 4 | majholi
# Processing Record 2 of Set 4 | erzin
# Processing Record 3 of Set 4 | shiraz
# Processing Record 4 of Set 4 | kurumkan
# Processing Record 5 of Set 4 | castro
# Processing Record 6 of Set 4 | san pedro
# Processing Record 7 of Set 4 | saint george
# Processing Record 8 of Set 4 | alofi
# Processing Record 9 of Set 4 | paredon
# Processing Record 10 of Set 4 | cockburn town
# Processing Record 11 of Set 4 | sogne
# Processing Record 12 of Set 4 | cherskiy
# Processing Record 13 of Set 4 | aflu
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 4 | conakry
# Processing Record 15 of Set 4 | lebu
# Processing Record 16 of Set 4 | atuona
# Processing Record 17 of Set 4 | saint-philippe
# Processing Record 18 of Set 4 | hobart
# Processing Record 19 of Set 4 | iqaluit
# Processing Record 20 of Set 4 | karauzyak
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 4 | georgiyevskoye
# Processing Record 22 of Set 4 | bonavista
# Processing Record 23 of Set 4 | tuktoyaktuk
# Processing Record 24 of Set 4 | verkhnevilyuysk
# Processing Record 25 of Set 4 | coos bay
# Processing Record 26 of Set 4 | sri aman
# Processing Record 27 of Set 4 | airai
# Processing Record 28 of Set 4 | saint-pascal
# 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 4 | kolpashevo
# Processing Record 30 of Set 4 | san carlos de bariloche
# Processing Record 31 of Set 4 | umm durman
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 4 | linxia
# Processing Record 33 of Set 4 | arraial do cabo
# Processing Record 34 of Set 4 | kavieng
# Processing Record 35 of Set 4 | cidreira
# Processing Record 36 of Set 4 | salalah
# Processing Record 37 of Set 4 | aquiraz
# Processing Record 38 of Set 4 | felidhoo
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 4 | neepawa
# Processing Record 40 of Set 4 | bartica
# Processing Record 41 of Set 4 | marfino
# Processing Record 42 of Set 4 | okhotsk
# Processing Record 43 of Set 4 | pevek
# Processing Record 44 of Set 4 | pisco
# Processing Record 45 of Set 4 | basna
# Processing Record 46 of Set 4 | umba
# Processing Record 47 of Set 4 | dubenskiy
# 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 4 | monte alegre
# Processing Record 49 of Set 4 | cape town
# Processing Record 50 of Set 4 | kholmogory
# Processing Record 1 of Set 5 | baykit
# Processing Record 2 of Set 5 | carnarvon
# Processing Record 3 of Set 5 | tasiilaq
# Processing Record 4 of Set 5 | svetlyy
# Processing Record 5 of Set 5 | lambarene
# Processing Record 6 of Set 5 | fortuna
# Processing Record 7 of Set 5 | takhatpur
# Processing Record 8 of Set 5 | tocopilla
# Processing Record 9 of Set 5 | bethel
# Processing Record 10 of Set 5 | mvomero
# Processing Record 11 of Set 5 | cayenne
# Processing Record 12 of Set 5 | tsihombe
# 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 5 | inuvik
# Processing Record 14 of Set 5 | thompson
# Processing Record 15 of Set 5 | bengkulu
# Processing Record 16 of Set 5 | zhigansk
# Processing Record 17 of Set 5 | chortomlyk
# Processing Record 18 of Set 5 | ushumun
# Processing Record 19 of Set 5 | ventspils
# Processing Record 20 of Set 5 | lisakovsk
# Processing Record 21 of Set 5 | port blair
# Processing Record 22 of Set 5 | kadoma
# Processing Record 23 of Set 5 | san vicente
# Processing Record 24 of Set 5 | dikson
# Processing Record 25 of Set 5 | fort nelson
# Processing Record 26 of Set 5 | mogadishu
# Processing Record 27 of Set 5 | urumqi
# Processing Record 28 of Set 5 | north bend
# Processing Record 29 of Set 5 | kazerun
# Processing Record 30 of Set 5 | adrar
# Processing Record 31 of Set 5 | cerro cama
# Processing Record 32 of Set 5 | narsaq
# Processing Record 33 of Set 5 | grand river south east
# 'coord'
# City not found. Skipping...
# Processing Record 34 of Set 5 | burnie
# Processing Record 35 of Set 5 | porto novo
# Processing Record 36 of Set 5 | kholodnyy
# Processing Record 37 of Set 5 | saleaula
# 'coord'
# City not found. Skipping...
# Processing Record 38 of Set 5 | amderma
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 5 | sibu
# Processing Record 40 of Set 5 | aksarka
# Processing Record 41 of Set 5 | gat
# Processing Record 42 of Set 5 | sorong
# Processing Record 43 of Set 5 | dondo
# Processing Record 44 of Set 5 | chuy
# Processing Record 45 of Set 5 | ostrozac
# Processing Record 46 of Set 5 | aksu
# Processing Record 47 of Set 5 | nikolskoye
# Processing Record 48 of Set 5 | yanam
# Processing Record 49 of Set 5 | churintzio
# Processing Record 50 of Set 5 | buchanan
# Processing Record 1 of Set 6 | mareeba
# Processing Record 2 of Set 6 | rocha
# Processing Record 3 of Set 6 | mahebourg
# Processing Record 4 of Set 6 | guerrero negro
# Processing Record 5 of Set 6 | timbiqui
# Processing Record 6 of Set 6 | vitim
# Processing Record 7 of Set 6 | el alto
# Processing Record 8 of Set 6 | owando
# Processing Record 9 of Set 6 | abu samrah
# Processing Record 10 of Set 6 | sauce
# Processing Record 11 of Set 6 | edd
# Processing Record 12 of Set 6 | mnogovershinnyy
# Processing Record 13 of Set 6 | sao filipe
# Processing Record 14 of Set 6 | chagda
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 6 | kahului
# Processing Record 16 of Set 6 | hihifo
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 6 | aljezur
# Processing Record 18 of Set 6 | jamestown
# Processing Record 19 of Set 6 | ribeira grande
# Processing Record 20 of Set 6 | kodiak
# Processing Record 21 of Set 6 | yulara
# Processing Record 22 of Set 6 | atar
# Processing Record 23 of Set 6 | los algarrobos
# Processing Record 24 of Set 6 | gamba
# Processing Record 25 of Set 6 | hervey bay
# Processing Record 26 of Set 6 | susanville
# Processing Record 27 of Set 6 | borogontsy
# Processing Record 28 of Set 6 | tiznit
# Processing Record 29 of Set 6 | bandundu
# Processing Record 30 of Set 6 | port-gentil
# Processing Record 31 of Set 6 | almaznyy
# Processing Record 32 of Set 6 | mumford
# Processing Record 33 of Set 6 | talnakh
# Processing Record 34 of Set 6 | luwingu
# Processing Record 35 of Set 6 | dolbeau
# 'coord'
# City not found. Skipping...
# Processing Record 36 of Set 6 | havelock
# Processing Record 37 of Set 6 | port hedland
# Processing Record 38 of Set 6 | port lincoln
# Processing Record 39 of Set 6 | orange
# Processing Record 40 of Set 6 | nanortalik
# Processing Record 41 of Set 6 | paamiut
# Processing Record 42 of Set 6 | vardo
# Processing Record 43 of Set 6 | kuytun
# Processing Record 44 of Set 6 | san quintin
# Processing Record 45 of Set 6 | padang
# Processing Record 46 of Set 6 | la ronge
# Processing Record 47 of Set 6 | mariental
# Processing Record 48 of Set 6 | santa ana
# Processing Record 49 of Set 6 | urfa
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 6 | port macquarie
# Processing Record 1 of Set 7 | biltine
# Processing Record 2 of Set 7 | provost
# Processing Record 3 of Set 7 | nakonde
# Processing Record 4 of Set 7 | ahipara
# Processing Record 5 of Set 7 | lusambo
# Processing Record 6 of Set 7 | bubaque
# Processing Record 7 of Set 7 | manado
# Processing Record 8 of Set 7 | floro
# Processing Record 9 of Set 7 | bereda
# Processing Record 10 of Set 7 | saint-augustin
# Processing Record 11 of Set 7 | meulaboh
# Processing Record 12 of Set 7 | tinley park
# Processing Record 13 of Set 7 | hualmay
# Processing Record 14 of Set 7 | yar-sale
# Processing Record 15 of Set 7 | pali
# Processing Record 16 of Set 7 | eureka
# Processing Record 17 of Set 7 | barrow
# Processing Record 18 of Set 7 | katobu
# Processing Record 19 of Set 7 | dungarpur
# Processing Record 20 of Set 7 | mount isa
# Processing Record 21 of Set 7 | lavrentiya
# Processing Record 22 of Set 7 | rongcheng
# Processing Record 23 of Set 7 | mora
# Processing Record 24 of Set 7 | tutoia
# Processing Record 25 of Set 7 | bose
# Processing Record 26 of Set 7 | payakumbuh
# Processing Record 27 of Set 7 | utiroa
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 7 | malakal
# Processing Record 29 of Set 7 | havre-saint-pierre
# Processing Record 30 of Set 7 | abha
# Processing Record 31 of Set 7 | fare
# Processing Record 32 of Set 7 | chifeng
# Processing Record 33 of Set 7 | salinopolis
# Processing Record 34 of Set 7 | hebertville
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 7 | fairbanks
# Processing Record 36 of Set 7 | emerald
# Processing Record 37 of Set 7 | gornopravdinsk
# Processing Record 38 of Set 7 | diffa
# Processing Record 39 of Set 7 | galveston
# Processing Record 40 of Set 7 | beyneu
# Processing Record 41 of Set 7 | mahon
# Processing Record 42 of Set 7 | morgan city
# Processing Record 43 of Set 7 | yumen
# Processing Record 44 of Set 7 | tessalit
# Processing Record 45 of Set 7 | abu dhabi
# Processing Record 46 of Set 7 | kuching
# Processing Record 47 of Set 7 | vaitupu
# 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 7 | hassleholm
# Processing Record 49 of Set 7 | jiddah
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 7 | mehamn
# Processing Record 1 of Set 8 | alugan
# Processing Record 2 of Set 8 | kuah
# Processing Record 3 of Set 8 | abnub
# Processing Record 4 of Set 8 | south lake tahoe
# Processing Record 5 of Set 8 | dzaoudzi
# Processing Record 6 of Set 8 | tsiroanomandidy
# Processing Record 7 of Set 8 | manibaug
# Processing Record 8 of Set 8 | tuatapere
# Processing Record 9 of Set 8 | nome
# Processing Record 10 of Set 8 | saint anthony
# Processing Record 11 of Set 8 | lagoa
# Processing Record 12 of Set 8 | hearst
# Processing Record 13 of Set 8 | kisarawe
# Processing Record 14 of Set 8 | bam
# Processing Record 15 of Set 8 | kadykchan
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 8 | nishihara
# Processing Record 17 of Set 8 | dhekiajuli
# Processing Record 18 of Set 8 | udachnyy
# Processing Record 19 of Set 8 | batagay-alyta
# Processing Record 20 of Set 8 | kjopsvik
# Processing Record 21 of Set 8 | saint-ambroise
# Processing Record 22 of Set 8 | pulsano
# Processing Record 23 of Set 8 | yuli
# Processing Record 24 of Set 8 | kyle of lochalsh
# 'coord'
# City not found. Skipping...
# Processing Record 25 of Set 8 | lyuban
# Processing Record 26 of Set 8 | kutum
# Processing Record 27 of Set 8 | olimpia
# Processing Record 28 of Set 8 | balkanabat
# Processing Record 29 of Set 8 | rawson
# Processing Record 30 of Set 8 | ostrovnoy
# Processing Record 31 of Set 8 | vaitape
# Processing Record 32 of Set 8 | nuuk
# Processing Record 33 of Set 8 | warqla
# 'coord'
# City not found. Skipping...
# Processing Record 34 of Set 8 | noyakert
# Processing Record 35 of Set 8 | formoso do araguaia
# 'coord'
# City not found. Skipping...
# Processing Record 36 of Set 8 | odweyne
# Processing Record 37 of Set 8 | broome
# Processing Record 38 of Set 8 | labuhan
# Processing Record 39 of Set 8 | tacoronte
# Processing Record 40 of Set 8 | merauke
# Processing Record 41 of Set 8 | chipiona
# Processing Record 42 of Set 8 | mount gambier
# Processing Record 43 of Set 8 | manggar
# Processing Record 44 of Set 8 | molln
# Processing Record 45 of Set 8 | lorengau
# Processing Record 46 of Set 8 | villa maria
# Processing Record 47 of Set 8 | saldanha
# Processing Record 48 of Set 8 | samana
# Processing Record 49 of Set 8 | taltal
# Processing Record 50 of Set 8 | jablanica
# Processing Record 1 of Set 9 | kuhestan
# 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 9 | portree
# Processing Record 3 of Set 9 | ulagan
# Processing Record 4 of Set 9 | constitucion
# Processing Record 5 of Set 9 | umm kaddadah
# Processing Record 6 of Set 9 | sokoni
# Processing Record 7 of Set 9 | kidal
# Processing Record 8 of Set 9 | luwuk
# Processing Record 9 of Set 9 | quatre cocos
# Processing Record 10 of Set 9 | kalomo
# 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 9 | senador jose porfirio
# Processing Record 12 of Set 9 | behbahan
# Processing Record 13 of Set 9 | seoul
# Processing Record 14 of Set 9 | ahumada
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 9 | goiatuba
# Processing Record 16 of Set 9 | ishigaki
# Processing Record 17 of Set 9 | coquimbo
# Processing Record 18 of Set 9 | shalyhyne
# Processing Record 19 of Set 9 | palmer
# Processing Record 20 of Set 9 | esso
# Processing Record 21 of Set 9 | broken hill
# Processing Record 22 of Set 9 | sawtell
# Processing Record 23 of Set 9 | hokitika
# Processing Record 24 of Set 9 | ukiah
# Processing Record 25 of Set 9 | kudahuvadhoo
# Processing Record 26 of Set 9 | souillac
# Processing Record 27 of Set 9 | mattru
# Processing Record 28 of Set 9 | khorixas
# Processing Record 29 of Set 9 | anloga
# Processing Record 30 of Set 9 | nguruka
# Processing Record 31 of Set 9 | caramay
# Processing Record 32 of Set 9 | darhan
# Processing Record 33 of Set 9 | dingle
# Processing Record 34 of Set 9 | husavik
# Processing Record 35 of Set 9 | the valley
# Processing Record 36 of Set 9 | iberia
# Processing Record 37 of Set 9 | aklavik
# Processing Record 38 of Set 9 | labelle
# Processing Record 39 of Set 9 | amahai
# Processing Record 40 of Set 9 | ulundi
# Processing Record 41 of Set 9 | trapani
# Processing Record 42 of Set 9 | gouyave
# Processing Record 43 of Set 9 | codrington
# Processing Record 44 of Set 9 | belmonte
# Processing Record 45 of Set 9 | porto torres
# Processing Record 46 of Set 9 | gumdag
# Processing Record 47 of Set 9 | lazurne
# Processing Record 48 of Set 9 | tunduru
# 'coord'
# City not found. Skipping...
# Processing Record 49 of Set 9 | veracruz
# Processing Record 50 of Set 9 | nguiu
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 10 | fukue
# Processing Record 2 of Set 10 | novaya zaimka
# Processing Record 3 of Set 10 | anar darreh
# 'coord'
# City not found. Skipping...
# Processing Record 4 of Set 10 | korla
# Processing Record 5 of Set 10 | aswan
# Processing Record 6 of Set 10 | kharp
# Processing Record 7 of Set 10 | el rosal
# Processing Record 8 of Set 10 | novyy svit
# Processing Record 9 of Set 10 | christchurch
# Processing Record 10 of Set 10 | amontada
# Processing Record 11 of Set 10 | victoria
# Processing Record 12 of Set 10 | bafq
# Processing Record 13 of Set 10 | itoigawa
# Processing Record 14 of Set 10 | laguna de perlas
# Processing Record 15 of Set 10 | porto empedocle
# Processing Record 16 of Set 10 | pingliang
# Processing Record 17 of Set 10 | youkounkoun
# Processing Record 18 of Set 10 | lethem
# Processing Record 19 of Set 10 | waldoboro
# Processing Record 20 of Set 10 | samarinda
# Processing Record 21 of Set 10 | nanae
# Processing Record 22 of Set 10 | kirakira
# Processing Record 23 of Set 10 | brae
# Processing Record 24 of Set 10 | severo-kurilsk
# Processing Record 25 of Set 10 | geraldton
# Processing Record 26 of Set 10 | soloneshnoye
# Processing Record 27 of Set 10 | vila
# Processing Record 28 of Set 10 | hasaki
# Processing Record 29 of Set 10 | marcona
# 'coord'
# City not found. Skipping...
# Processing Record 30 of Set 10 | kyzyl-suu
# Processing Record 31 of Set 10 | satitoa
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 10 | neyshabur
# Processing Record 33 of Set 10 | wecker
# Processing Record 34 of Set 10 | akdepe
# Processing Record 35 of Set 10 | esperance
# Processing Record 36 of Set 10 | kuche
# 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 10 | malwan
# 'coord'
# City not found. Skipping...
# Processing Record 38 of Set 10 | huai mek
# Processing Record 39 of Set 10 | kholuy
# Processing Record 40 of Set 10 | westport
# Processing Record 41 of Set 10 | samusu
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 10 | agua dulce
# Processing Record 43 of Set 10 | kamenskoye
# 'coord'
# City not found. Skipping...
# Processing Record 44 of Set 10 | mandera
# Processing Record 45 of Set 10 | tautira
# Processing Record 46 of Set 10 | luena
# Processing Record 47 of Set 10 | sitka
# Processing Record 48 of Set 10 | grand gaube
# Processing Record 49 of Set 10 | nosy varika
# Processing Record 50 of Set 10 | san patricio
# Processing Record 1 of Set 11 | cairns
# Processing Record 2 of Set 11 | alibag
# Processing Record 3 of Set 11 | lagos
# Processing Record 4 of Set 11 | bathsheba
# Processing Record 5 of Set 11 | hami
# Processing Record 6 of Set 11 | tateyama
# Processing Record 7 of Set 11 | umzimvubu
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 11 | burkhala
# 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 11 | horuphav
# Processing Record 10 of Set 11 | san vicente de canete
# Processing Record 11 of Set 11 | laguna
# Processing Record 12 of Set 11 | tiarei
# Processing Record 13 of Set 11 | sisimiut
# Processing Record 14 of Set 11 | tidore
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 11 | killybegs
# Processing Record 16 of Set 11 | pathein
# Processing Record 17 of Set 11 | san ignacio
# Processing Record 18 of Set 11 | magadi
# Processing Record 19 of Set 11 | tezu
# Processing Record 20 of Set 11 | polson
# Processing Record 21 of Set 11 | isoka
# Processing Record 22 of Set 11 | russell
# Processing Record 23 of Set 11 | nabire
# Processing Record 24 of Set 11 | kingman
# Processing Record 25 of Set 11 | odesa
# Processing Record 26 of Set 11 | sioux lookout
# Processing Record 27 of Set 11 | kedrovyy
# Processing Record 28 of Set 11 | najran
# Processing Record 29 of Set 11 | andros town
# Processing Record 30 of Set 11 | la linea
# Processing Record 31 of Set 11 | boende
# Processing Record 32 of Set 11 | beeville
# Processing Record 33 of Set 11 | yurga
# Processing Record 34 of Set 11 | tanta
# Processing Record 35 of Set 11 | morondava
# Processing Record 36 of Set 11 | vila velha
# Processing Record 37 of Set 11 | bayanday
# Processing Record 38 of Set 11 | guadalajara
# Processing Record 39 of Set 11 | trinidad
# Processing Record 40 of Set 11 | barra patuca
# Processing Record 41 of Set 11 | tubuala
# Processing Record 42 of Set 11 | mayor pablo lagerenza
# Processing Record 43 of Set 11 | aliwal north
# Processing Record 44 of Set 11 | meyungs
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 11 | coihaique
# Processing Record 46 of Set 11 | hay river
# Processing Record 47 of Set 11 | mendi
# Processing Record 48 of Set 11 | tabas
# Processing Record 49 of Set 11 | buin
# Processing Record 50 of Set 11 | along
# Processing Record 1 of Set 12 | kieta
# Processing Record 2 of Set 12 | kutahya
# Processing Record 3 of Set 12 | zgorzelec
# Processing Record 4 of Set 12 | codajas
# Processing Record 5 of Set 12 | northam
# Processing Record 6 of Set 12 | tinskoy
# Processing Record 7 of Set 12 | liuzhou
# Processing Record 8 of Set 12 | oytal
# Processing Record 9 of Set 12 | mwingi
# Processing Record 10 of Set 12 | margate
# Processing Record 11 of Set 12 | pacific grove
# Processing Record 12 of Set 12 | neryungri
# Processing Record 13 of Set 12 | humaita
# Processing Record 14 of Set 12 | romitan
# Processing Record 15 of Set 12 | ilulissat
# Processing Record 16 of Set 12 | lata
# Processing Record 17 of Set 12 | linguere
# Processing Record 18 of Set 12 | hopelchen
# Processing Record 19 of Set 12 | shingu
# Processing Record 20 of Set 12 | te anau
# Processing Record 21 of Set 12 | afonso claudio
# Processing Record 22 of Set 12 | bambous virieux
# Processing Record 23 of Set 12 | komsomolskiy
# Processing Record 24 of Set 12 | ayorou
# Processing Record 25 of Set 12 | chernyshevskiy
# Processing Record 26 of Set 12 | atuntaqui
# Processing Record 27 of Set 12 | villazon
# Processing Record 28 of Set 12 | katsiveli
# 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 12 | ferkessedougou
# Processing Record 30 of Set 12 | mocuba
# Processing Record 31 of Set 12 | lishui
# Processing Record 32 of Set 12 | mantua
# Processing Record 33 of Set 12 | molteno
# Processing Record 34 of Set 12 | indiana
# Processing Record 35 of Set 12 | bonthe
# Processing Record 36 of Set 12 | abu zabad
# Processing Record 37 of Set 12 | flic en flac
# Processing Record 38 of Set 12 | matagami
# Processing Record 39 of Set 12 | luba
# Processing Record 40 of Set 12 | tucdao
# Processing Record 41 of Set 12 | sobolevo
# Processing Record 42 of Set 12 | hays
# Processing Record 43 of Set 12 | swellendam
# Processing Record 44 of Set 12 | vilyuysk
# Processing Record 45 of Set 12 | nyahururu
# Processing Record 46 of Set 12 | shreveport
# Processing Record 47 of Set 12 | harper
# Processing Record 48 of Set 12 | garissa
# Processing Record 49 of Set 12 | kusk
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 12 | jamtara
# Processing Record 1 of Set 13 | urucara
# Processing Record 2 of Set 13 | flinders
# Processing Record 3 of Set 13 | palabuhanratu
# 'coord'
# City not found. Skipping...
# Processing Record 4 of Set 13 | zlatoustovsk
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 13 | toliary
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 13 | louisbourg
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 13 | jijiga
# Processing Record 8 of Set 13 | sao jose da coroa grande
# Processing Record 9 of Set 13 | yerbogachen
# Processing Record 10 of Set 13 | kayfan
# 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 13 | muisne
# Processing Record 12 of Set 13 | iquitos
# Processing Record 13 of Set 13 | worland
# Processing Record 14 of Set 13 | ngama
# Processing Record 15 of Set 13 | talara
# Processing Record 16 of Set 13 | anjozorobe
# Processing Record 17 of Set 13 | rapid valley
# Processing Record 18 of Set 13 | ramgarh
# Processing Record 19 of Set 13 | virginia beach
# Processing Record 20 of Set 13 | katsuura
# Processing Record 21 of Set 13 | mataram
# Processing Record 22 of Set 13 | sudislavl
# Processing Record 23 of Set 13 | iskateley
# Processing Record 24 of Set 13 | dolores
# Processing Record 25 of Set 13 | gushikawa
# Processing Record 26 of Set 13 | kushiro
# Processing Record 27 of Set 13 | canutama
# Processing Record 28 of Set 13 | puerto colombia
# Processing Record 29 of Set 13 | samarai
# Processing Record 30 of Set 13 | miles city
# Processing Record 31 of Set 13 | richards bay
# Processing Record 32 of Set 13 | moerai
# Processing Record 33 of Set 13 | puerto ayacucho
# Processing Record 34 of Set 13 | rio de janeiro
# Processing Record 35 of Set 13 | nemuro
# Processing Record 36 of Set 13 | kiama
# Processing Record 37 of Set 13 | mildura
# Processing Record 38 of Set 13 | takoradi
# Processing Record 39 of Set 13 | ketchikan
# Processing Record 40 of Set 13 | bilibino
# Processing Record 41 of Set 13 | karasburg
# Processing Record 42 of Set 13 | shelburne
# Processing Record 43 of Set 13 | kokopo
# Processing Record 44 of Set 13 | uttaradit
# Processing Record 45 of Set 13 | roswell
# Processing Record 46 of Set 13 | lucea
# Processing Record 47 of Set 13 | marzuq
# Processing Record 48 of Set 13 | creston
# Processing Record 49 of Set 13 | yuzhno-kurilsk
# Processing Record 50 of Set 13 | waddan
# Processing Record 1 of Set 14 | dickinson
# Processing Record 2 of Set 14 | shimoda
# Processing Record 3 of Set 14 | avera
# Processing Record 4 of Set 14 | leshan
# Processing Record 5 of Set 14 | porto santo
# Processing Record 6 of Set 14 | falealupo
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 14 | rungata
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 14 | qaqortoq
# Processing Record 9 of Set 14 | leshukonskoye
# Processing Record 10 of Set 14 | suzu
# 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 14 | svetlaya
# Processing Record 12 of Set 14 | havoysund
# Processing Record 13 of Set 14 | hofn
# Processing Record 14 of Set 14 | north myrtle beach
# Processing Record 15 of Set 14 | dvinskoy
# Processing Record 16 of Set 14 | agha jari
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 14 | ocampo
# Processing Record 18 of Set 14 | vao
# Processing Record 19 of Set 14 | tumannyy
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 14 | lazaro cardenas
# Processing Record 21 of Set 14 | okha
# Processing Record 22 of Set 14 | rio gallegos
# Processing Record 23 of Set 14 | vestmannaeyjar
# Processing Record 24 of Set 14 | alice springs
# Processing Record 25 of Set 14 | raga
# Processing Record 26 of Set 14 | indiaroba
# Processing Record 27 of Set 14 | lolua
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 14 | brainerd
# Processing Record 29 of Set 14 | acapulco
# Processing Record 30 of Set 14 | norden
# Processing Record 31 of Set 14 | melchor de mencos
# Processing Record 32 of Set 14 | nata
# Processing Record 33 of Set 14 | senanga
# Processing Record 34 of Set 14 | cazaje
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 14 | oriximina
# Processing Record 36 of Set 14 | half moon bay
# Processing Record 37 of Set 14 | tura
# Processing Record 38 of Set 14 | skjervoy
# Processing Record 39 of Set 14 | singapore
# Processing Record 40 of Set 14 | kungurtug
# Processing Record 41 of Set 14 | punta alta
# Processing Record 42 of Set 14 | ocara
# Processing Record 43 of Set 14 | fuerte olimpo
# Processing Record 44 of Set 14 | gidole
# Processing Record 45 of Set 14 | beatrice
# Processing Record 46 of Set 14 | matara
# Processing Record 47 of Set 14 | kaeo
# Processing Record 48 of Set 14 | bintulu
# Processing Record 49 of Set 14 | belyy yar
# Processing Record 50 of Set 14 | puerto del rosario
# Processing Record 1 of Set 15 | moyo
# Processing Record 2 of Set 15 | maniitsoq
# Processing Record 3 of Set 15 | grootfontein
# Processing Record 4 of Set 15 | fethiye
# Processing Record 5 of Set 15 | opuwo
# Processing Record 6 of Set 15 | buqayq
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 15 | kytlym
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 15 | saint-joseph
# Processing Record 9 of Set 15 | irbil
# Processing Record 10 of Set 15 | baoying
# Processing Record 11 of Set 15 | vaasa
# Processing Record 12 of Set 15 | auki
# Processing Record 13 of Set 15 | juneau
# Processing Record 14 of Set 15 | duz
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 15 | arica
# Processing Record 16 of Set 15 | aripuana
# Processing Record 17 of Set 15 | chaman
# Processing Record 18 of Set 15 | kailahun
# Processing Record 19 of Set 15 | wonthaggi
# Processing Record 20 of Set 15 | hachinohe
# Processing Record 21 of Set 15 | valparaiso
# Processing Record 22 of Set 15 | santiago de cao
# Processing Record 23 of Set 15 | caravelas
# Processing Record 24 of Set 15 | dukat
# Processing Record 25 of Set 15 | nanpiao
# Processing Record 26 of Set 15 | sinnamary
# Processing Record 27 of Set 15 | karratha
# Processing Record 28 of Set 15 | itaituba
# Processing Record 29 of Set 15 | kouango
# Processing Record 30 of Set 15 | mount hagen
# Processing Record 31 of Set 15 | bell ville
# Processing Record 32 of Set 15 | trojes
# Processing Record 33 of Set 15 | brownwood
# Processing Record 34 of Set 15 | gangotri
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 15 | chernivtsi
# Processing Record 36 of Set 15 | oum hadjer
# Processing Record 37 of Set 15 | waingapu
# Processing Record 38 of Set 15 | severnyy
# Processing Record 39 of Set 15 | eldorado
# Processing Record 40 of Set 15 | monrovia
# Processing Record 41 of Set 15 | turukhansk
# Processing Record 42 of Set 15 | vasto
# Processing Record 43 of Set 15 | kenai
# Processing Record 44 of Set 15 | mergui
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 15 | andenes
# Processing Record 46 of Set 15 | luangwa
# Processing Record 47 of Set 15 | aberdeen
# Processing Record 48 of Set 15 | port hardy
# Processing Record 49 of Set 15 | lappeenranta
# Processing Record 50 of Set 15 | touros
# Processing Record 1 of Set 16 | nouadhibou
# Processing Record 2 of Set 16 | bakchar
# Processing Record 3 of Set 16 | jacmel
# Processing Record 4 of Set 16 | temaraia
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 16 | muros
# Processing Record 6 of Set 16 | los llanos de aridane
# Processing Record 7 of Set 16 | lahti
# Processing Record 8 of Set 16 | antalaha
# Processing Record 9 of Set 16 | dunedin
# Processing Record 10 of Set 16 | xingyi
# Processing Record 11 of Set 16 | nyurba
# Processing Record 12 of Set 16 | honningsvag
# Processing Record 13 of Set 16 | ondorhaan
# 'coord'
# City not found. Skipping...
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %%
#Convert the array of dictionaries to a Pandas DataFrame
city_data_df= pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# 0                    Russell  32.3502  -85.1999     85.98        65
# 1                      Vaini -21.2000 -175.2000     74.30        56
# 2  Petropavlovsk-Kamchatskiy  53.0452  158.6483     39.79       100
# 3                  Busselton -33.6500  115.3333     56.08        76
# 4                       Hilo  19.7297 -155.0900     71.80        73
# 5                      Ancud -41.8697  -73.8203     49.53        73
# 6                   Pandhana  21.7000   76.2167     85.64        54
# 7                      Colon   9.3592  -79.9014     92.25        76
# 8                    Rikitea -23.1203 -134.9692     75.33        80
# 9          Sao Joao Da Barra -21.6403  -41.0511     78.89        74
#
#    Cloudiness  Wind Speed Country Current Description
# 0          75        3.47      US       broken clouds
# 1         100       13.40      TO     overcast clouds
# 2          90       17.54      RU          light rain
# 3          12       10.85      AU          few clouds
# 4          75        3.44      US       broken clouds
# 5          80        2.15      CL       broken clouds
# 6          56        3.42      IN       broken clouds
# 7          53        4.00      PA       broken clouds
# 8         100       10.11      PF     overcast clouds
# 9          12        5.61      BR          few clouds

# %%
new_column_order= ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df= city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                         City Country      Lat       Lng  Max Temp  Humidity  \
# 0                    Russell      US  32.3502  -85.1999     85.98        65
# 1                      Vaini      TO -21.2000 -175.2000     74.30        56
# 2  Petropavlovsk-Kamchatskiy      RU  53.0452  158.6483     39.79       100
# 3                  Busselton      AU -33.6500  115.3333     56.08        76
# 4                       Hilo      US  19.7297 -155.0900     71.80        73
# 5                      Ancud      CL -41.8697  -73.8203     49.53        73
# 6                   Pandhana      IN  21.7000   76.2167     85.64        54
# 7                      Colon      PA   9.3592  -79.9014     92.25        76
# 8                    Rikitea      PF -23.1203 -134.9692     75.33        80
# 9          Sao Joao Da Barra      BR -21.6403  -41.0511     78.89        74
#
#    Cloudiness  Wind Speed Current Description
# 0          75        3.47       broken clouds
# 1         100       13.40     overcast clouds
# 2          90       17.54          light rain
# 3          12       10.85          few clouds
# 4          75        3.44       broken clouds
# 5          80        2.15       broken clouds
# 6          56        3.42       broken clouds
# 7          53        4.00       broken clouds
# 8         100       10.11     overcast clouds
# 9          12        5.61          few clouds

# %%
#Create the output file (CSV)
output_data_file= "Weather_Database/WeatherPy_Database.csv"
#Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label= "City_ID")
